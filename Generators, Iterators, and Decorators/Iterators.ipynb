# %%
prices = []

with open("pricing.txt", "r") as f:
    for line in f:
        ticker, country, price, date = line.split("|")
        prices.append({
            'ticker': ticker,
            'country': country,
            'price': float(price),
            'date': date.strip()
        })

# %%
prices
# Out:
# [{'ticker': 'MSFT', 'country': 'BRA', 'price': 381.26, 'date': '2023-10-27'},
#  {'ticker': 'CSCO', 'country': 'USA', 'price': 187.64, 'date': '2023-02-12'},
#  {'ticker': 'INTC', 'country': 'CAN', 'price': 173.25, 'date': '2023-04-11'},
#  {'ticker': 'INTC', 'country': 'BRA', 'price': 172.87, 'date': '2023-11-16'},
#  {'ticker': 'NVDA', 'country': 'GBR', 'price': 374.54, 'date': '2023-05-14'},
#  {'ticker': 'CSCO', 'country': 'IND', 'price': 292.89, 'date': '2023-04-20'},
#  {'ticker': 'MSFT', 'country': 'CAN', 'price': 210.3, 'date': '2023-12-17'},
#  {'ticker': 'AAPL', 'country': 'DEU', 'price': 234.3, 'date': '2023-10-20'},
#  {'ticker': 'AMZN', 'country': 'AUS', 'price': 127.56, 'date': '2023-05-02'},
#  {'ticker': 'NFLX', 'country': 'CAN', 'price': 214.84, 'date': '2023-12-09'},
#  {'ticker': 'AAPL', 'country': 'FRA', 'price': 305.09, 'date': '2023-12-22'},
#  {'ticker': 'AAPL', 'country': 'BRA', 'price': 302.94, 'date': '2023-01-11'},
# ...

# %%
#We are interested in __iter__ and __next__
dir(f)
# Out:
# ['_CHUNK_SIZE',
#  '__class__',
#  '__del__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__next__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '_checkClosed',
#  '_checkReadable',
#  '_checkSeekable',
#  '_checkWritable',
#  '_finalizing',
#  'buffer',
#  'close',
#  'closed',
#  'detach',
#  'encoding',
#  'errors',
#  'fileno',
#  'flush',
#  'isatty',
#  'line_buffering',
#  'mode',
#  'name',
#  'newlines',
#  'read',
#  'readable',
#  'readline',
#  'readlines',
#  'reconfigure',
#  'seek',
#  'seekable',
#  'tell',
#  'truncate',
#  'writable',
#  'write',
#  'write_through',
#  'writelines']

# %%
f = open("pricing.txt", "r")

iterator = iter(f)
iterator
# Out:
# <_io.TextIOWrapper name='pricing.txt' mode='r' encoding='UTF-8'>

# %%
next(iterator)
# Out:
# 'MSFT|BRA|381.26|2023-10-27\n'

# %%
next(iterator)
# Out:
# 'CSCO|USA|187.64|2023-02-12\n'

# %% [markdown]
# Internally, when we do a for loop with a file, the computer will run the next and iterator to loop over all the lines and gives us the various lines
