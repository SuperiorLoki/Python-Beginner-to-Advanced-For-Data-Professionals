# %% [markdown]
# We will be doing exploratory data analytics with both plain python and pandas in this tutorial

# %%
#Plain python code:
import csv


def calculate_rating_stats(data, industry=None):
    ratings = []
    for row in data:
        if row[3]!='NULL' and (not industry or row[1] == industry):
            ratings.append(float(row[3]))
    max_rating = max(ratings)
    min_rating = min(ratings)
    avg_rating = sum(ratings) / len(ratings)
    return max_rating, min_rating, avg_rating


with open("movies.csv") as f:
    data1 = list(csv.reader(f))
    header = data1[0]
    data = data1[1:]

    max_rating, min_rating, avg_rating = calculate_rating_stats(data)
    print(f"All records: Min Rating = {min_rating}, Max Rating = {max_rating}, Average Rating = {avg_rating}")

    max_rating, min_rating, avg_rating = calculate_rating_stats(data,industry="Bollywood")
    print(f"Bollywood: Min Rating = {min_rating}, Max Rating = {max_rating}, Average Rating = {avg_rating}")

    max_rating, min_rating, avg_rating = calculate_rating_stats(data, industry="Hollywood")
    print(f"Hollywood: Min Rating = {min_rating}, Max Rating = {max_rating}, Average Rating = {avg_rating}")
# Out:
# All records: Min Rating = 1.9, Max Rating = 9.3, Average Rating = 7.922222222222223
# Bollywood: Min Rating = 1.9, Max Rating = 8.4, Average Rating = 7.6625000000000005
# Hollywood: Min Rating = 6.8, Max Rating = 9.3, Average Rating = 8.130000000000003

# %% [markdown]
# Movie Analysis Using Pandas

# %%
#With Pandas:
import pandas as pd

df = pd.read_csv("movies.csv")
df
# Out:
#                                           title   industry  release_year  \
# 0                               Pather Panchali  Bollywood          1955
# 1   Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                          Thor: The Dark World  Hollywood          2013
# 3                                Thor: Ragnarok  Hollywood          2017
# 4                        Thor: Love and Thunder  Hollywood          2022
# 5                      The Shawshank Redemption  Hollywood          1994
# 6                                  Interstellar  Hollywood          2014
# 7                      The Pursuit of Happyness  Hollywood          2006
# 8                                     Gladiator  Hollywood          2000
# 9                                       Titanic  Hollywood          1997
# 10                        It's a Wonderful Life  Hollywood          1946
# 11                                       Avatar  Hollywood          2009
# ...

# %%
#to print the first few rows
df.head(3)
# Out:
#                                          title   industry  release_year  \
# 0                              Pather Panchali  Bollywood          1955
# 1  Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                         Thor: The Dark World  Hollywood          2013
#
#    imdb_rating                     studio   budget   revenue       unit  \
# 0          8.3  Government of West Bengal  70000.0  100000.0  Thousands
# 1          7.0             Marvel Studios    200.0     954.8   Millions
# 2          6.8             Marvel Studios    165.0     644.8   Millions
#
#   currency language
# 0      INR  Bengali
# 1      USD  English
# 2      USD  English

# %%
#to print last few rows
df.tail(3)
# Out:
#                         title   industry  release_year  imdb_rating  \
# 34  Pushpa: The Rise - Part 1  Bollywood          2021          7.6
# 35                        RRR  Bollywood          2022          8.0
# 36   Baahubali: The Beginning  Bollywood          2015          8.0
#
#                  studio  budget  revenue      unit currency language
# 34  Mythri Movie Makers     2.0      3.6  Billions      INR   Telugu
# 35    DVV Entertainment     5.5     12.0  Billions      INR   Telugu
# 36     Arka Media Works     1.8      6.5  Billions      INR   Telugu

# %%
#to randomly print random rows
df.sample(4)
# Out:
#                      title   industry  release_year  imdb_rating  \
# 18  Avengers: Infinity War  Hollywood          2018          8.4
# 16                Parasite  Hollywood          2019          8.5
# 12           The Godfather  Hollywood          1972          9.2
# 31                  Race 3  Bollywood          2018          1.9
#
#                 studio  budget  revenue      unit currency language
# 18      Marvel Studios   400.0   2048.0  Millions      USD  English
# 16                 NaN    15.5    263.1  Millions      USD  English
# 12  Paramount Pictures     7.2    291.0  Millions      USD  English
# 31   Salman Khan Films     1.8      3.1  Billions      INR    Hindi

# %%
#print certain index to index operations (rows 2-5)
df[2:6]
# Out:
#                       title   industry  release_year  imdb_rating  \
# 2      Thor: The Dark World  Hollywood          2013          6.8
# 3            Thor: Ragnarok  Hollywood          2017          7.9
# 4    Thor: Love and Thunder  Hollywood          2022          6.8
# 5  The Shawshank Redemption  Hollywood          1994          9.3
#
#                       studio  budget  revenue      unit currency language
# 2             Marvel Studios   165.0    644.8  Millions      USD  English
# 3             Marvel Studios   180.0    854.0  Millions      USD  English
# 4             Marvel Studios   250.0    670.0  Millions      USD  English
# 5  Castle Rock Entertainment    25.0     73.3  Millions      USD  English

# %%
#This will tell us that the table is 37 rows and 10 columns
df.shape
# Out:
# (37, 10)

# %%
df.imdb_rating
# Out:
# 0     8.3
# 1     7.0
# 2     6.8
# 3     7.9
# 4     6.8
# 5     9.3
# 6     8.6
# 7     8.0
# 8     8.5
# 9     7.9
# 10    8.6
# 11    7.8
# 12    9.2
# 13    9.0
# 14    9.0
# 15    8.2
# 16    8.5
# 17    8.4
# 18    8.4
# 19    6.9
# 20    7.8
# 21    8.1
# 22    8.4
# 23    7.4
# 24    7.2
# 25    8.3
# 26    8.1
# 27    8.1
# 28    NaN
# 29    8.3
# 30    8.1
# 31    1.9
# 32    8.4
# 33    8.4
# 34    7.6
# 35    8.0
# 36    8.0
# Name: imdb_rating, dtype: float64

# %%
#dir(df.imdb_rating) to find all of its functions

# %%
#This is all you need with pandas to find the min max and average
df.imdb_rating.min(), df.imdb_rating.max(), df.imdb_rating.mean()
# Out:
# (1.9, 9.3, 7.922222222222222)

# %%
df_bollywood = df[df.industry=="Bollywood"]
df_hollywood = df[df.industry=="Hollywood"]

# %%
df_bollywood.imdb_rating.min(), df_bollywood.imdb_rating.max(), df_bollywood.imdb_rating.mean()
# Out:
# (1.9, 8.4, 7.6625000000000005)

# %%
df_hollywood.imdb_rating.min(), df_hollywood.imdb_rating.max(), df_hollywood.imdb_rating.mean()
# Out:
# (6.8, 9.3, 8.130000000000003)

# %%
#Final Code:
df_bollywood = df[df.industry=="Bollywood"]
df_hollywood = df[df.industry=="Hollywood"]

df_bollywood.imdb_rating.min(), df_bollywood.imdb_rating.max(), df_bollywood.imdb_rating.mean()
df_hollywood.imdb_rating.min(), df_hollywood.imdb_rating.max(), df_hollywood.imdb_rating.mean()

max_rating, min_rating, avg_rating = calculate_rating_stats(data)
print(f"All records: Min Rating = {df.imdb_rating.min()}, Max Rating = {df.imdb_rating.max()}, Average Rating = {df.imdb_rating.mean()}")

max_rating, min_rating, avg_rating = calculate_rating_stats(data,industry="Bollywood")
print(f"Bollywood: Min Rating = {df_bollywood.imdb_rating.min()}, Max Rating = {df_bollywood.imdb_rating.max()}, Average Rating = {df_bollywood.imdb_rating.mean()}")

max_rating, min_rating, avg_rating = calculate_rating_stats(data, industry="Hollywood")
print(f"Hollywood: Min Rating = {df_hollywood.imdb_rating.min()}, Max Rating = {df_hollywood.imdb_rating.max()}, Average Rating = {avg_rating}")
